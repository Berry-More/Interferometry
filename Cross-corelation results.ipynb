# %%
import os
import numpy as np
import obspy as obs
import plotly.graph_objects as go
from scipy.signal import correlate, butter, lfilter
from numpy.fft import rfft, irfft, fft, ifft

# %%
def sub_mid(array):
    return array - array.mean()


def taper(data):
    length = int(len(data)*5//1000)
    ox = [i/length*np.pi/2 for i in range(length)]
    sinus = np.sin(ox)/max(np.sin(ox))
    data[:length] = data[:length] * sinus
    data[(len(data)-length):] = data[(len(data)-length):] * sinus[::-1]
    return data


def sub_tap(stream):
    for i in range(len(stream)):
        stream[i].data = taper(sub_mid(stream[i].data))


def one_bit(array):
    array[array>0] = 1
    array[array<0] = -1
    return array


def whitening(array):
    spectre = rfft(array)
    new_array = irfft(spectre/np.abs(spectre))
    return new_array


def window_correlation(array1, array2, window):
    all_corr = np.zeros(window)
    iterations = len(array1)//window
    for i in range(iterations):
        all_corr += correlate(array1[i*window:(i+1)*window], array2[i*window:(i+1)*window], mode='same')
    return all_corr

# %%
def draw(x, y, title, xrange):
    fig = go.Figure()
    fig.add_trace(
        go.Scatter(x=x, 
                   y=y, 
                   showlegend=False))
    fig.update_layout(title=title,
                      template='seaborn')
    fig.update_xaxes(range=range)
    fig.show()

# %%
stp = obs.read('https://raw.github.com/ashimrijal/NoiseCorrelation/master/data/noise.CI.MLAC.LHZ.2004.294.2005.017.mseed')
stp += obs.read('https://raw.github.com/ashimrijal/NoiseCorrelation/master/data/noise.CI.PHL.LHZ.2004.294.2005.017.mseed')

# %%
minutes = 60 # Размер окна в минутах

# Параметры фильтра
lowcut = 0.1
highcut = 0.2

stn = stp.copy()
t = stn[0].stats.starttime
stn.trim(t, t + 4 * 86400-1)

sub_tap(stn)
stn.filter('bandpass', freqmin=lowcut, freqmax=highcut, zerophase=True)
# Out:
# 8 Trace(s) in Stream:
# CI.MLAC..LHZ | 2004-10-20T00:00:00.230799Z - 2004-10-21T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-21T00:00:00.230799Z - 2004-10-22T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-22T00:00:00.230799Z - 2004-10-23T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-23T00:00:00.230799Z - 2004-10-23T23:59:59.230799Z | 1.0 Hz, 86400 samples
# CI.PHL..LHZ  | 2004-10-20T00:00:00.000000Z - 2004-10-21T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ  | 2004-10-21T00:00:00.000000Z - 2004-10-22T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ  | 2004-10-22T00:00:00.000000Z - 2004-10-23T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ  | 2004-10-23T00:00:00.000000Z - 2004-10-23T23:59:59.000000Z | 1.0 Hz, 86400 samples

# %%
fs = stn[0].stats.sampling_rate
window_size = int(minutes*60*fs)
osx = np.linspace(-window_size/(2*fs), window_size/(2*fs), window_size)

# %%
first = stn[0:4]
second = stn[4::]
first, second
# Out:
# (4 Trace(s) in Stream:
# CI.MLAC..LHZ | 2004-10-20T00:00:00.230799Z - 2004-10-21T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-21T00:00:00.230799Z - 2004-10-22T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-22T00:00:00.230799Z - 2004-10-23T00:00:00.230799Z | 1.0 Hz, 86401 samples
# CI.MLAC..LHZ | 2004-10-23T00:00:00.230799Z - 2004-10-23T23:59:59.230799Z | 1.0 Hz, 86400 samples,
#  4 Trace(s) in Stream:
# CI.PHL..LHZ | 2004-10-20T00:00:00.000000Z - 2004-10-21T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ | 2004-10-21T00:00:00.000000Z - 2004-10-22T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ | 2004-10-22T00:00:00.000000Z - 2004-10-23T00:00:00.000000Z | 1.0 Hz, 86401 samples
# CI.PHL..LHZ | 2004-10-23T00:00:00.000000Z - 2004-10-23T23:59:59.000000Z | 1.0 Hz, 86400 samples)

# %%
big_correlation = np.zeros(window_size)

for i in range(len(first)):
    array1 = first[i].data
    array2 = second[i].data
    
    array1, array2 = whitening(array1), whitening(array2)  # Вайтенинг спектра
    array1, array2 = one_bit(array1), one_bit(array2)  # Однобитная нормализация
    
    big_correlation += window_correlation(array1, array2, window_size)

# %%
draw(osx, big_correlation, 'Cross-corelation', (-200, 200))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12936/3480090558.py in <module>
# ----> 1 draw(osx, big_correlation, 'Cross-corelation', (-200, 200))
#
# ~\AppData\Local\Temp/ipykernel_12936/3444967393.py in draw(x, y, title, xrange)
#       7     fig.update_layout(title=title,
#       8                       template='seaborn')
# ----> 9     fig.update_xaxes(range=range)
#      10     fig.show()
#
# D:\Temp\Anaconda\lib\site-packages\plotly\graph_objs\_figure.py in update_xaxes(self, patch, selector, overwrite, row, col, **kwargs)
#   18167         """
#   18168         for obj in self.select_xaxes(selector=selector, row=row, col=col):
# > 18169             obj.update(patch, overwrite=overwrite, **kwargs)
#   18170
#   18171         return self
#
# D:\Temp\Anaconda\lib\site-packages\plotly\basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    4769             with self.figure.batch_update():
#    4770                 BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 4771                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    4772         else:
#    4773             BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# D:\Temp\Anaconda\lib\site-packages\plotly\basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3655                 else:
#    3656                     # Assign non-compound value
# -> 3657                     plotly_obj[key] = val
#    3658
#    3659         elif isinstance(plotly_obj, tuple):
#
# D:\Temp\Anaconda\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4532                 # ### Handle simple property ###
#    4533                 else:
# -> 4534                     self._set_prop(prop, value)
#    4535             else:
#    4536                 # Make sure properties dict is initialized
#
# D:\Temp\Anaconda\lib\site-packages\plotly\basedatatypes.py in _set_prop(self, prop, val)
#    4850                 return
#    4851             else:
# -> 4852                 raise err
#    4853
#    4854         # val is None
#
# D:\Temp\Anaconda\lib\site-packages\plotly\basedatatypes.py in _set_prop(self, prop, val)
#    4845
#    4846         try:
# -> 4847             val = validator.validate_coerce(val)
#    4848         except ValueError as err:
#    4849             if self._skip_invalid:
#
# D:\Temp\Anaconda\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v)
#    2119             return None
#    2120         elif not is_array(v):
# -> 2121             self.raise_invalid_val(v)
#    2122
#    2123         # Save off original v value to use in error reporting
#
# D:\Temp\Anaconda\lib\site-packages\_plotly_utils\basevalidators.py in raise_invalid_val(self, v, inds)
#     283                 typ=type_str(v),
#     284                 v=repr(v),
# --> 285                 valid_clr_desc=self.description(),
#     286             )
#     287         )
#
# ValueError:
#     Invalid value of type 'builtins.range' received for the 'range' property of layout.xaxis
#         Received value: <class 'range'>
#
#     The 'range' property is an info array that may be specified as:
#
#     * a list or tuple of 2 elements where:
# (0) The 'range[0]' property accepts values of any type
# (1) The 'range[1]' property accepts values of any type

# %%
f = open('american_correlation.txt')
american = []
for i in f:
    american.append(float(i))

# %%
len(american)
# Out:
# 7201

# %%
len(big_correlation)
# Out:
# 3600

# %%
f1 = np.array(american[3600-1800:3600+1800])
f2 = big_correlation
line_x = np.linspace(-len(f1)/2, len(f1)/2, len(f1))

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(x=line_x, 
                y=f1/max(f1), name='American colleagues',
                showlegend=True))
fig.add_trace(
    go.Scatter(x=line_x, 
                y=f2/max(f2), name='My',
                showlegend=True))
fig.update_layout(title='Comparison of results', 
                    template='seaborn')
fig.show()
# Out:
# <div>                            <div id="94076941-d8af-4a5f-8bf1-1006d2266881" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94076941-d8af-4a5f-8bf1-1006d2266881")) {                    Plotly.newPlot(                        "94076941-d8af-4a5f-8bf1-1006d2266881",                        [{"name": "American", "showlegend": true, "type": "scatter", "x": [-1800.0, -1798.9997221450403, -1797.9994442900806, -1796.999166435121, -1795.998888580161, -1794.9986107252014, -1793.9983328702417, -1792.998055015282, -1791.9977771603224, -1790.9974993053627, -1789.9972214504028, -1788.996943595443, -1787.9966657404834, -1786.9963878855237, -1785.996110030564, -1784.9958321756044, -1783.9955543206447, -1782.9952764656848, -1781.9949986107251, -1780.9947207557655, -1779.9944429